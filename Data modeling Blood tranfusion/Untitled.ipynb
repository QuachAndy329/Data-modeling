# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.model_selection import train_test_split as tts
from sklearn import metrics

# %%
df = pd.read_csv('transfusion.data',sep=',', header = 0)

# %%
pd.set_option('display.max_columns', 999)
pd.set_option('display.max_rows', 999)

# %%
df.shape
# Out:
# (748, 5)

# %%
df.columns
# Out:
# Index(['Recency (months)', 'Frequency (times)', 'Monetary (c.c. blood)',
#        'Time (months)', 'whether he/she donated blood in March 2007'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Recency (months)                              int64
# Frequency (times)                             int64
# Monetary (c.c. blood)                         int64
# Time (months)                                 int64
# whether he/she donated blood in March 2007    int64
# dtype: object

# %%
df[0:748]
# Out:
#      Recency (months)  Frequency (times)  Monetary (c.c. blood)  \
# 0                   2                 50                  12500
# 1                   0                 13                   3250
# 2                   1                 16                   4000
# 3                   2                 20                   5000
# 4                   1                 24                   6000
# 5                   4                  4                   1000
# 6                   2                  7                   1750
# 7                   1                 12                   3000
# 8                   2                  9                   2250
# 9                   5                 46                  11500
# 10                  4                 23                   5750
# 11                  0                  3                    750
# 12                  2                 10                   2500
# 13                  1                 13                   3250
# ...

# %% [markdown]
# # relationship of Monetary, Time and Donations

# %% [markdown]
# ## Monetary relationship with Time and Donations

# %%
df.plot.scatter(x='Time (months)',y='Monetary (c.c. blood)',figsize=(20,10), color= "red")
# Out:
# <AxesSubplot:xlabel='Time (months)', ylabel='Monetary (c.c. blood)'>

# %%
df.plot.scatter(x='whether he/she donated blood in March 2007',y='Monetary (c.c. blood)',figsize=(20,10), color= "red")

# %%
df.plot.scatter(x= "Time (months)", y="Monetary (c.c. blood)", c="whether he/she donated blood in March 2007",sharex=False,colormap="viridis",figsize=(20,10))

# %% [markdown]
# ## Relationship between Time and Donations

# %%
df.plot.bar(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.barh(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.box(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.area(x= "Time (months)", y="whether he/she donated blood in March 2007")

# %%
df.plot.hexbin(x= "Time (months)", y="whether he/she donated blood in March 2007")

# %%
df.plot.hist(x= "whether he/she donated blood in March 2007", y="Time (months)",bins=20)

# %%
df.plot.kde(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.line(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.pie(x= "whether he/she donated blood in March 2007", y="Time (months)")

# %%
df.plot.scatter(x= "whether he/she donated blood in March 2007", y="Time (months)",figsize=(20,10))
